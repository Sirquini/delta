# %%
import numpy as np
from collections import deque
from itertools import product

# %%
from cached_property import cached_property
from importlib import reload
import dynamic_poset
reload(dynamic_poset)
from dynamic_poset import Poset, PosetStorage
from poset_storage import KVStorage, Population


def example(P):
    global L,T
    L = P.meta_L
    T = Poset.total(L.n-1)
    print('P and L:')
    P.show()
    L.show()
    print('~P x P:')
    (~P*P).show()
    P.meta_PP.show()
    print('~T x T:')
    (~T*T).enumerated.show()
    print('-'*5)
    return 

example(Poset.total(2)|Poset.total(1))

example(Poset.from_children([[],[],[0,1],[0]]))
# Out:
# P and L:
# ~P x P:
# ~T x T:
# -----
# P and L:
# ~P x P:
# ~T x T:
# -----

# %%
from importlib import reload
import dynamic_poset
reload(dynamic_poset)
from dynamic_poset import Poset

T = Poset.total(7)
Poset((~T*T).canonical.leq).show()

T = Poset.total(7)
Poset((~T*T).leq).show()

# %%
P = Poset.total(2)|Poset.total(1)
P.show()
((~P).meta_L * P.meta_L).show()
(~P.meta_L * P.meta_L).show()
((~P * P).meta_L.enumerated).show()

# %%
P = Poset.total(2)|Poset.total(1)
print(P.n)
print(((~P).meta_L * P.meta_L).n)
print((~P.meta_L * P.meta_L).n)
print(((~P * P).meta_L).n)
# Out:
# 3
# 36
# 36
# 108

# %%
from importlib import reload
import dynamic_poset
reload(dynamic_poset)
from dynamic_poset import Poset

P = Poset.total(2)|Poset.total(1)
#(~P.meta_L * P.meta_L).standard.show()
((~P * P).meta_L.enumerated).show()

# %%
P = Poset.from_children([[],[],[0,1],[0]])

((~P).meta_L * P.meta_L).enumerated.show()
((~Poset.total(P.meta_L.n-1)).meta_L * Poset.total(P.meta_L.n-1).meta_L).enumerated.show()
